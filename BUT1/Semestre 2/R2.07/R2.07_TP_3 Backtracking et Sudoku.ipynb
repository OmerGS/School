# %% [markdown]
# ***
#
# # R2.07
# ## TP3. Backtracking et Sudoku
#
#
# ***
# ***
#
#
# Le but de ce TP est de comprendre le backtracking (version récursive et itérative) et d'adapter cette méthode à différents problèmes (assez similaires).

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#magic
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Implémentation récursive :
#
# ChatGPT propose cette implémentation pour le backtracking récursive du Sudoku.
#
# **Question 1**
# >Comprendre et tester ce programme

# %%
def is_valid(board, row, col, num):
    # Vérifie si le nombre est déjà présent dans la ligne
    for x in range(9):
        if board[row][x] == num:
            return False

    # Vérifie si le nombre est déjà présent dans la colonne
    for x in range(9):
        if board[x][col] == num:
            return False

    # Vérifie si le nombre est déjà présent dans la boîte 3x3
    start_row = row - row % 3
    start_col = col - col % 3
    for i in range(3):
        for j in range(3):
            if board[i + start_row][j + start_col] == num:
                return False

    return True



def find_empty_location(board, l):
    for row in range(9):
        for col in range(9):
            if board[row][col] == 0:
                l[0] = row
                l[1] = col
                return True
    return False

def solve_sudoku(board):
    l = [0, 0]

    # Si il n'y a plus d'emplacement vide, le sudoku est résolu
    if not find_empty_location(board, l):
        return True

    row = l[0]
    col = l[1]

    # Essaye les chiffres de 1 à 9
    for num in range(1, 10):
        # Si le chiffre est valide
        if is_valid(board, row, col, num):
            # Affecte le chiffre à l'emplacement
            board[row][col] = num

            # Résout récursivement le reste du sudoku
            if solve_sudoku(board):
                return True

            # Si aucune solution n'est trouvée, annule l'assignation et essaye un autre chiffre
            board[row][col] = 0

    # Si aucun chiffre ne fonctionne, retourne False
    return False

# Exemple de grille de Sudoku (0 représente une case vide)
board = [
    [5, 3, 0, 0, 7, 0, 0, 0, 0],
    [6, 0, 0, 1, 9, 5, 0, 0, 0],
    [0, 9, 8, 0, 0, 0, 0, 6, 0],
    [8, 0, 0, 0, 6, 0, 0, 0, 3],
    [4, 0, 0, 8, 0, 3, 0, 0, 1],
    [7, 0, 0, 0, 2, 0, 0, 0, 6],
    [0, 6, 0, 0, 0, 0, 2, 8, 0],
    [0, 0, 0, 4, 1, 9, 0, 0, 5],
    [0, 0, 0, 0, 8, 0, 0, 7, 9]
]

if solve_sudoku(board):
    for row in board:
        print(row)
else:
    print("Pas de solution possible.")

# %% [markdown]
# **Question 2**
# >Modifier et tester ce programme pour le problème du Shidoku (grille $4\times 4$) comme présenté dans le CM2

# %%
def getNbLigne(board):  
    #1 = nbColonne
    #0 = nbLigne
    #dimension = np.shape(board)
    #return(dimension[0])
    return(4)


def getNbColonne(board):  
    #1 = nbColonne
    #0 = nbLigne
    #dimension = np.shape(board)
    #return(dimension[1])
    return(4)


def is_valid(board, row, col, num):
    # Vérifie si le nombre est déjà présent dans la ligne
    for x in range(getNbLigne(board)):
        if board[row][x] == num:
            return False

    # Vérifie si le nombre est déjà présent dans la colonne
    for x in range(getNbColonne(board)):
        if board[x][col] == num:
            return False

    # Vérifie si le nombre est déjà présent dans la matrice
    start_row = row - row
    start_col = col - col
    for i in range(getNbLigne(board)):
        for j in range(getNbColonne(board)):
            if board[i + start_row][j + start_col] == num:
                return False

    return True



def find_empty_location(board, l):
    for row in range(getNbLigne(board)):
        for col in range(getNbColonne(board)):
            if board[row][col] == 0:
                l[0] = row
                l[1] = col
                return True
    return False

def solve_sudoku(board):
    l = [0, 0]

    # Si il n'y a plus d'emplacement vide, le sudoku est résolu
    if not find_empty_location(board, l):
        return True

    row = l[0]
    col = l[1]

    # Essaye les chiffres de 1 à la taille du sudoku
    for num in range(1, getNbLigne(board)):
        # Si le chiffre est valide
        if is_valid(board, row, col, num):
            # Affecte le chiffre à l'emplacement
            board[row][col] = num

            # Résout récursivement le reste du sudoku
            if solve_sudoku(board):
                return True

            # Si aucune solution n'est trouvée, annule l'assignation et essaye un autre chiffre
            board[row][col] = 0

    # Si aucun chiffre ne fonctionne, retourne False
    return False


# Exemple de grille de Shidoku (0 représente une case vide)
board1 = [
    [ 0, 0, 0, 0],
    [ 3, 0, 2, 0],
    [ 0, 0, 0, 0],
    [ 4, 0, 0, 1],
]

board = [
    [0,1,0,4],
    [0,0,0,0],
    [2,0,0,3],
    [0,0,0,0],
]

liste_sudoku = [board1, board]

for i in range(len(liste_sudoku)):
    board = liste_sudoku[i]
    if solve_sudoku(board):
        for row in board:
            print(row)
    else:
        print("\nPas de solution possible.")
        for row in board:
            print(row)

# %% [markdown]
# ## Implémentation itérative
#
# ChatGPT propose cette implémentation (non fonctionnelle) pour le backtracking itératif du Sudoku.
#
# **Question 3**
# >Corriger le programme afin qu'il fonctionne.

# %%
tested_value = []
nb_conf = 0

def getNbConf():
    global nb_conf
    return(nb_conf)

def cleanup_tested_value():
    global tested_value

    tested_value = []


def is_valid(board, row, col, num):
    # Vérifie si le nombre est déjà présent dans la ligne
    for x in range(9):
        if board[row][x] == num:
            return False

    # Vérifie si le nombre est déjà présent dans la colonne
    for x in range(9):
        if board[x][col] == num:
            return False

    # Vérifie si le nombre est déjà présent dans la boîte 3x3
    start_row = row - row % 3
    start_col = col - col % 3
    for i in range(3):
        for j in range(3):
            if board[i + start_row][j + start_col] == num:
                return False

    return True

def find_empty_location(board):
    # Trouve et retourne la prochaine case vide dans la grille
    for row in range(9):
        for col in range(9):
            if board[row][col] == 0:
                return row, col
    return None, None

def solve_sudoku(board):
    global tested_value, nb_conf

    stack = []
    cnt= 0
    while True:
        
        # Trouve la prochaine case vide
        row, col = find_empty_location(board)

        # Si toutes les cases sont remplies, le sudoku est résolu
        if row is None:
            return True

        # Essaye les chiffres de 1 à 9
        found = False
        for num in range(1, 10):
            # Si le chiffre est valide
            if is_valid(board, row, col, num) and not tested_value:
                # Affecte le chiffre à l'emplacement
                board[row][col] = num
                stack.append((row, col, num))
                found = True
                
                nb_conf = nb_conf+1
                break

        # Si aucun chiffre n'est valide pour cette case, annule et retourne en arrière
        if not found:
            while stack:
                tested_value.append(num)
                row, col, num = stack.pop()
                board[row][col] = 0           
                if num < 9:
                    found = True
                    break
            if not found:
                tested_value = {}
                return False

# Exemple de grille de Sudoku (0 représente une case vide)
board = [
    [5, 3, 0, 0, 7, 0, 0, 0, 0],
    [6, 0, 0, 1, 9, 5, 0, 0, 0],
    [0, 9, 8, 0, 0, 0, 0, 6, 0],
    [8, 0, 0, 0, 6, 0, 0, 0, 3],
    [4, 0, 0, 8, 0, 3, 0, 0, 1],
    [7, 0, 0, 0, 2, 0, 0, 0, 6],
    [0, 6, 0, 0, 0, 0, 2, 8, 0],
    [0, 0, 0, 4, 1, 9, 0, 0, 5],
    [0, 0, 0, 0, 8, 0, 0, 7, 9]
]

if solve_sudoku(board):
    for row in board:
        print(row)
else:
    print("Pas de solution possible.")
# Out:
# Pas de solution possible.

# %% [markdown]
# **Question 3**
# >Ajouter un compteur et tracer en fonction de $n$ le nombre de configurations explorées. Comparer avec le nombre de configurations totales qui seraient à examiner lors d'une résolution brute-force

# %%
print(getNbConf())
print(2**81)
# Out:
# 5
# 2417851639229258349412352
# 2.0679515313825692e-24

# %% [markdown]
# **Question 3**
# >Adapter le code précédent (ou le code donné par ChatGPT ci-dessous) afin qu'il résolve le problème des $4$-dames (puis des [$n$-dames](https://fr.wikipedia.org/wiki/Probl%C3%A8me_des_huit_dames)) **en stockant toutes les solutions**.<br>
# >Ajouter un compteur et tracer en fonction de $n$ le nombre de configurations explorées. Comparer avec le nombre de configurations totales qui seraient à examiner lors d'une résolution brute-force

# %%
####Ne fonctionne pas !


def is_safe(board, row, col):
    # Vérifie la colonne
    for i in range(row):
        if board[i][col] == 1:
            return False

    # Vérifie la diagonale supérieure gauche
    for i, j in zip(range(row, -1, -1), range(col, -1, -1)):
        if board[i][j] == 1:
            return False

    # Vérifie la diagonale supérieure droite
    for i, j in zip(range(row, -1, -1), range(col, len(board))):
        if board[i][j] == 1:
            return False

    return True

def solve_n_queens(n):
    solutions = []
    stack = []

    # Crée un plateau vide NxN
    board = [[0] * n for _ in range(n)]

    row = 0
    col = 0

    while True:
        # Place une reine dans la colonne actuelle de la ligne actuelle
        while col < n:
            if is_safe(board, row, col):
                board[row][col] = 1
                stack.append(col)
                col = 0
                break
            col += 1

        # Si aucune colonne n'est sûre dans cette ligne, annule et retourne en arrière
        if col == n:
            if not stack:
                break
            last_col = stack.pop()
            board[row][last_col] = 0
            col = last_col + 1
            row -= 1
            continue

        # Si toutes les reines sont placées, ajoute la solution et annule la dernière reine
        if row == n - 1:
            solutions.append([row[:] for row in board])
            last_col = stack.pop()
            board[row][last_col] = 0
            col = last_col + 1
            row -= 1
            continue

        # Passe à la ligne suivante
        row += 1

    return solutions

# Exemple pour résoudre le problème des 8 dames
n = 8
solutions = solve_n_queens(n)
print(f"Nombre de solutions pour {n}-dames : {len(solutions)}")
# Out:
# Nombre de solutions pour 8-dames : 0

# %% [markdown]
# **Question Bonus**
# >Tracer l'arbre d'exploration des configurations pour le problème des $4$-dames
